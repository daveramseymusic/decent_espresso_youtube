# %% [markdown]
# # Get StrataScratch Subscribers with .subscribers() Youtube API

# %%
# !pip install google-auth
# !pip install google-auth-oauthlib

# %%
import pandas as pd
import os
import pickle
import time
from os import path
from pathlib2 import Path
# import pathlib2 as pl

from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
import googleapiclient.discovery
import googleapiclient.errors

# %% [markdown]
# load credentials

# %%
credentials = None
# token.pickle stores the user's credentials from previously successful logins
if os.path.exists('token.pickle'):
    print('Loading Credentials From File...')
    with open('token.pickle', 'rb') as token:
        credentials = pickle.load(token)

# If there are no valid credentials available, then either refresh the token or log in.
if not credentials or not credentials.valid:
    if credentials and credentials.expired and credentials.refresh_token:
        print('Refreshing Access Token...')
        credentials.refresh(Request())
    else:
        print('Fetching New Tokens...')
        flow = InstalledAppFlow.from_client_secrets_file(
            'client_secrets.json',
            scopes=[
                'https://www.googleapis.com/auth/youtube.readonly'
            ]
        )

        flow.run_local_server(port=8080, prompt='consent')#,authorization_prompt_message='')
        credentials = flow.credentials

        # Save the credentials for the next run
        with open('token.pickle', 'wb') as f:
            print('Saving Credentials for Future Use...')
            pickle.dump(credentials, f)
# Out:
# Loading Credentials From File...
# Refreshing Access Token...

# %%
#Get first response for sub/comms subscriptions that are allowed:
def get_subcomms_subscriptions_first_response(channelId):
        api_service_name = "youtube"
        api_version = "v3"

        youtube = googleapiclient.discovery.build(api_service_name, api_version, credentials=credentials)
        request = youtube.subscriptions().list(part="snippet",channelId=channelId)
        # request = youtube.subscriptions().list(part="snippet,contentDetails",pageToken='CLYHEAE', maxResults=maxResults,mySubscribers=True)
        response = request.execute()
        return response, request, youtube

# %%
def get_subscriber_ids(df,response):
    for sub in response['items']:
        if sub['kind'] == 'youtube#subscription': 
            
            response_kind =sub['kind']
            publishedAt=sub['snippet']['publishedAt']
            channel_title =sub['snippet']['title']
            channel_description =sub['snippet']['description']
            channelId = sub['snippet']['resourceId']['channelId']
            sub_channelId = sub['snippet']['channelId']        

            try:
                if response['nextPageToken'] != None:
                    pageToken = response['nextPageToken']
                    df = df.append({'response_kind': response_kind, 'publishedAt':publishedAt, 'channel_title':channel_title,'channel_description':channel_description,'channelId':channelId,'sub_channelId':sub_channelId,'pageToken':pageToken},ignore_index=True)    
                else:
                    df = df.append({'response_kind': response_kind, 'publishedAt':publishedAt, 'channel_title':channel_title,'channelId':channelId,'sub_channelId':sub_channelId,'pageToken':'none'},ignore_index=True)    
            except Exception as e: 
                print('get_subs_ids error:')
                print(str(e))
                #save data in pandas df
                df = df.append({'response_kind': response_kind, 'publishedAt':publishedAt, 'channel_title':channel_title,'channelId':channelId,'sub_channelId':sub_channelId,'pageToken':'none'},ignore_index=True)
    
    return df

# %%
def get_subs_pagination(df,request,response,youtube):
    while 1:
        try:
            request = youtube.subscriptions().list_next(previous_request=request, previous_response=response)
            response = request.execute()
            df = get_subscriber_ids(df,response)
        
        except Exception as e: 
            print('get_subs_paginations error:')
            if 'you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.' in str(e):
                print(str(e))
                print(f'stopped at {current_chan_idx}')
                df = df[df.sub_channelId != channelId] # erase anything you just loaded because it's incomplete
                print(f'erased all from last Id  - {channelId}')    
            break
    
    return df,request,response

# %% [markdown]
# ## Main

# %% [markdown]
# #### Decent Note: start at 549 for more -- wednesday

# %%
# Manual Variables
#start=0
start=1091 #restarting here because an 'hit limii' error occurred during 594 but it kept goinng.  need to fix this...

cnname = 'decent' # channel nick name
mchannel_id = 'UCCXojfo44Qhwdg3zmOWIJ7A' #  main channel ID for the primegean
mchannel_name = 'Decent Espresso Machines'  # main channel name for 'ThePrimeagen'

comments_csv = 'decent_espresso_machines_UCCXojfo44Qhwdg3zmOWIJ7A_youtube_comments_3453rows.csv'

goal = start + 110

start
# Out:
# 1091

# %%
#main
exceptions_count=0
last_start =start # in case we need to start again at the last spot
dfo = pd.read_csv(comments_csv,low_memory=False)

dfo = dfo.loc[dfo.response_kind!='youtube#video']
dfo = dfo.reset_index(drop=True)

chan_ids = dfo.authorChannelId.unique() # create chan_ids from imported df for all youtube scraping:
# chan_ids = chan_ids[1:]  #this used to be necessary ,but now you've cleaned up dfo before so you don't need it

df = pd.DataFrame()
# user_count = 0
# 

# goal = start + (len(chan_ids)-start)

#########Grab everything using this function
# df, last_user,exceptions_count = main_getter(df,chan_ids=chan_ids,start=start,exceptions_count=exceptions_count)

for channelId in chan_ids[start:goal]:
    attempting = goal - start
    current_chan_idx = list(chan_ids).index(channelId)
    total_overall = len(chan_ids)
    try:        
        response ,request, youtube = get_subcomms_subscriptions_first_response(channelId)
        #turn first response to df
        df = get_subscriber_ids(df,response)
        print('df length: ' + str(len(df)))
        
        df,request,response = get_subs_pagination(df=df,response=response ,request=request, youtube=youtube)
        last_unique_scId = df.loc[df.index[-1],'sub_channelId']
        user_count = df.sub_channelId.nunique()
        last_Id_idx = list(chan_ids).index(last_unique_scId)
        
        #tracker to make sure its doing what it says
        print(f'users collected this round: {user_count} / error ct: {exceptions_count} / attempting this round: {attempting}')
        print(f'start: {start} / at: {current_chan_idx} / goal: {goal} / All Possible Commenters: {total_overall}')
    
    except Exception as e: 
                
        #tracker to make sure its doing what it says
                  
        print(f'users collected this round: {user_count} / error ct: {exceptions_count} / attempting this round: {attempting}')
        print(f'start: {start} / at: {current_chan_idx} / goal: {goal} / All Possible Commenters: {total_overall}')

        exceptions_count +=1
        print('main getter error')
        
        #if not allowed error
        if 'not allowed to access the requested subscriptions' in str(e):
            print('not allowed to access the requested subscriptions')
            pass

        #if cannot be found error
        elif 'subscriber identified with the request cannot be found' in str(e):
            print('subscriber identified with the request cannot be found')
            pass
        
        # if not allowed acces error
        elif 'not allowed to access the requested subscriptions' not in str(e):
            if 'you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.' in str(e):
                print(str(e))
                print(f'stopped at {current_chan_idx}')
                df = df[df.sub_channelId != channelId] # erase anything you just loaded because it's incomplete
                print(f'erased all from last Id  - {channelId}')
                break
            else:      
                print(str(e))
                df = df[df.sub_channelId != channelId] # erase anything you just loaded because it's incomplete
                print(f'erased all from last Id  - {channelId}')
                break
                pass
            
                
last_user = last_Id_idx #create last user variable to use for name

###
# last user should instead be last_Id_idx

###
df.to_csv(f'competitor_{cnname}_commenters_subscricptions_{start}_{last_user}.csv',index=False) # save as csv
print(f'Saved: competitor_{cnname}_commenters_subscriptions_{start}_{last_user}.csv') 


#create path object and filename to read/save to.
this_path = Path('/Users/davidramsey/Documents/coding/youtube_scraping/decent')
filename =f'{mchannel_name}_{mchannel_id}_coms_combined.csv'

if os.path.exists(this_path/filename):
    dfall = pd.read_csv(this_path/f'{mchannel_name}_{mchannel_id}_coms_combined.csv',lineterminator='\n',low_memory=False) #load combined csv
    print('dfall found')
    dfall = pd.concat([dfall,df]) # concat to new df
else:
    dfall = df
    print('no dfall found')

dfall = dfall.drop_duplicates() #drop allo= duplicates
dfall = dfall.reset_index(drop=True)

# save newly combined and print the number of unique users
dfall.to_csv(this_path/f'{mchannel_name}_{mchannel_id}_coms_combined.csv',index=False) ;
print('total combined Uniques: '+ str(dfall.sub_channelId.nunique() )+' / '+ str(dfo.authorChannelId.nunique())+' possible uniques')

# start=last_user #set up start for next time around
last_unique_scId = df.loc[df.index[-1],'sub_channelId']
last_Id_idx = list(chan_ids).index(last_unique_scId)

users_attempted = goal-start
users_pulled = df.sub_channelId.nunique()
length = len(dfall)
print(f'started: {start}/ ended: {current_chan_idx} / out of a total of '+ str(dfo.authorChannelId.nunique()))

print(f'users attmepted: {users_attempted} / users pulled {users_pulled} / exeptions this round: {exceptions_count}/ len of dfall: {length}' )

# start = last_Id_idx +1 #change the start for next time

#try this to waste less time:
start = current_chan_idx

# time.sleep(120)
df.tail(3)
# Out:
# df length: 5
# get_subs_ids error:
# 'nextPageToken'
# get_subs_ids error:
# 'nextPageToken'
# get_subs_ids error:
# 'nextPageToken'
# get_subs_ids error:
# 'nextPageToken'
# get_subs_paginations error:
# users collected this round: 1 / error ct: 0 / attempting this round: 110
# start: 1091 / at: 1091 / goal: 1201 / All Possible Commenters: 1191
# df length: 84
# get_subs_ids error:
# 'nextPageToken'
# get_subs_ids error:
# 'nextPageToken'
# get_subs_ids error:
# 'nextPageToken'
# get_subs_ids error:
# 'nextPageToken'
# get_subs_paginations error:
# users collected this round: 2 / error ct: 0 / attempting this round: 110
# start: 1091 / at: 1092 / goal: 1201 / All Possible Commenters: 1191
# df length: 171
# get_subs_ids error:
# 'nextPageToken'
# get_subs_paginations error:
# users collected this round: 3 / error ct: 0 / attempting this round: 110
# start: 1091 / at: 1093 / goal: 1201 / All Possible Commenters: 1191
# users collected this round: 3 / error ct: 0 / attempting this round: 110
# start: 1091 / at: 1094 / goal: 1201 / All Possible Commenters: 1191
# main getter error
# not allowed to access the requested subscriptions
# df length: 459
# get_subs_ids error:
# 'nextPageToken'
# get_subs_ids error:
# 'nextPageToken'
# get_subs_ids error:
# 'nextPageToken'
# get_subs_paginations error:
# users collected this round: 4 / error ct: 1 / attempting this round: 110
# start: 1091 / at: 1095 / goal: 1201 / All Possible Commenters: 1191
# df length: 1387
# get_subs_ids error:
# 'nextPageToken'
# get_subs_ids error:
# 'nextPageToken'
# get_subs_paginations error:
# users collected this round: 5 / error ct: 1 / attempting this round: 110
# start: 1091 / at: 1096 / goal: 1201 / All Possible Commenters: 1191
# df length: 1774
# get_subs_ids error:
# 'nextPageToken'
# get_subs_paginations error:
# users collected this round: 6 / error ct: 1 / attempting this round: 110
# start: 1091 / at: 1097 / goal: 1201 / All Possible Commenters: 1191
# df length: 1805
# get_subs_ids error:
# 'nextPageToken'
# get_subs_paginations error:
# users collected this round: 7 / error ct: 1 / attempting this round: 110
# start: 1091 / at: 1098 / goal: 1201 / All Possible Commenters: 1191
# users collected this round: 7 / error ct: 1 / attempting this round: 110
# start: 1091 / at: 1099 / goal: 1201 / All Possible Commenters: 1191
# main getter error
# not allowed to access the requested subscriptions
# users collected this round: 7 / error ct: 2 / attempting this round: 110
# start: 1091 / at: 1100 / goal: 1201 / All Possible Commenters: 1191
# main getter error
# not allowed to access the requested subscriptions
# users collected this round: 7 / error ct: 3 / attempting this round: 110
# start: 1091 / at: 1101 / goal: 1201 / All Possible Commenters: 1191
# main getter error
# not allowed to access the requested subscriptions
# users collected this round: 7 / error ct: 4 / attempting this round: 110
# start: 1091 / at: 1102 / goal: 1201 / All Possible Commenters: 1191
# main getter error
# not allowed to access the requested subscriptions
# users collected this round: 7 / error ct: 5 / attempting this round: 110
# start: 1091 / at: 1103 / goal: 1201 / All Possible Commenters: 1191
# main getter error
# not allowed to access the requested subscriptions
# users collected this round: 7 / error ct: 6 / attempting this round: 110
# start: 1091 / at: 1104 / goal: 1201 / All Possible Commenters: 1191
# main getter error
# not allowed to access the requested subscriptions
# df length: 1978
# get_subs_ids error:
# 'nextPageToken'
# get_subs_ids error:
# 'nextPageToken'
# get_subs_ids error:
# 'nextPageToken'
# get_subs_paginations error:
# users collected this round:
# get_subs_ids error:
# 'nextPageToken'
# get_subs_paginations error:
# users collected this round: 43 / error ct: 42 / attempting this round: 110
# start: 1091 / at: 1175 / goal: 1201 / All Possible Commenters: 1191
# get_subs_ids error:
# 'nextPageToken'
# get_subs_ids error:
# 'nextPageToken'
# get_subs_ids error:
# 'nextPageToken'
# df length: 8878
# get_subs_paginations error:
# users collected this round: 44 / error ct: 42 / attempting this round: 110
# start: 1091 / at: 1176 / goal: 1201 / All Possible Commenters: 1191
# users collected this round: 44 / error ct: 42 / attempting this round: 110
# start: 1091 / at: 1177 / goal: 1201 / All Possible Commenters: 1191
# main getter error
# not allowed to access the requested subscriptions
# df length: 8883
# get_subs_ids error:
# 'nextPageToken'
# get_subs_ids error:
# 'nextPageToken'
# get_subs_paginations error:
# users collected this round: 45 / error ct: 43 / attempting this round: 110
# start: 1091 / at: 1178 / goal: 1201 / All Possible Commenters: 1191
# df length: 8900
# get_subs_ids error:
# 'nextPageToken'
# get_subs_paginations error:
# users collected this round: 46 / error ct: 43 / attempting this round: 110
# start: 1091 / at: 1179 / goal: 1201 / All Possible Commenters: 1191
# users collected this round: 46 / error ct: 43 / attempting this round: 110
# start: 1091 / at: 1180 / goal: 1201 / All Possible Commenters: 1191
# main getter error
# not allowed to access the requested subscriptions
# df length: 8945
# get_subs_ids error:
# 'nextPageToken'
# get_subs_ids error:
# 'nextPageToken'
# get_subs_ids error:
# 'nextPageToken'
# get_subs_ids error:
# 'nextPageToken'
# get_subs_paginations error:
# users collected this round: 47 / error ct: 44 / attempting this round: 110
# start: 1091 / at: 1181 / goal: 1201 / All Possible Commenters: 1191
# users collected this round: 47 / error ct: 44 / attempting this round: 110
# start: 1091 / at: 1182 / goal: 1201 / All Possible Commenters: 1191
# main getter error
# not allowed to access the requested subscriptions
# users collected this round: 47 / error ct: 45 / attempting this round: 110
# start: 1091 / at: 1183 / goal: 1201 / All Possible Commenters: 1191
# main getter error
# not allowed to access the requested subscriptions
# df length: 9070
# get_subs_ids error:
# 'nextPageToken'
# get_subs_ids error:
# 'nextPageToken'
# get_subs_ids error:
# 'nextPageToken'
# get_subs_ids error:
# 'nextPageToken'
# get_subs_paginations error:
# users collected this round: 48 / error ct: 46 / attempting this round: 110
# start: 1091 / at: 1184 / goal: 1201 / All Possible Commenters: 1191
# users collected this round: 48 / error ct: 46 / attempting this round: 110
# start: 1091 / at: 1185 / goal: 1201 / All Possible Commenters: 1191
# main getter error
# not allowed to access the requested subscriptions
# df length: 9154
# get_subs_ids error:
# 'nextPageToken'
# get_subs_ids error:
# 'nextPageToken'
# get_subs_paginations error:
# users collected this round: 49 / error ct: 47 / attempting this round: 110
# start: 1091 / at: 1186 / goal: 1201 / All Possible Commenters: 1191
# users collected this round: 49 / error ct: 47 / attempting this round: 110
# start: 1091 / at: 1187 / goal: 1201 / All Possible Commenters: 1191
# main getter error
# not allowed to access the requested subscriptions
# df length: 9166
# get_subs_ids error:
# 'nextPageToken'
# get_subs_ids error:
# 'nextPageToken'
# get_subs_ids error:
# 'nextPageToken'
# get_subs_ids error:
# 'nextPageToken'
# get_subs_ids error:
# 'nextPageToken'
# get_subs_paginations error:
# users collected this round: 50 / error ct: 48 / attempting this round: 110
# start: 1091 / at: 1188 / goal: 1201 / All Possible Commenters: 1191
# df length: 9986
# get_subs_ids error:
# 'nextPageToken'
# get_subs_ids error:
# 'nextPageToken'
# get_subs_ids error:
# 'nextPageToken'
# get_subs_paginations error:
# users collected this round: 51 / error ct: 48 / attempting this round: 110
# start: 1091 / at: 1189 / goal: 1201 / All Possible Commenters: 1191
# df length: 10084
# get_subs_ids error:
# 'nextPageToken'
# get_subs_ids error:
# 'nextPageToken'
# get_subs_ids error:
# 'nextPageToken'
# get_subs_ids error:
# 'nextPageToken'
# get_subs_ids error:
# 'nextPageToken'
# get_subs_paginations error:
# users collected this round: 52 / error ct: 48 / attempting this round: 110
# start: 1091 / at: 1190 / goal: 1201 / All Possible Commenters: 1191
# Saved: competitor_decent_commenters_subscriptions_1091_1190.csv
# dfall found
# total combined Uniques: 507 / 1190 possible uniques
# started: 1091/ ended: 1190 / out of a total of 1190
# users attmepted: 110 / users pulled 52 / exeptions this round: 48/ len of dfall: 103269
#               response_kind                  publishedAt       channel_title  \
# 11012  youtube#subscription  2020-05-29T01:39:22.709246Z   Isaac Aaron Media
# 11013  youtube#subscription         2015-11-24T06:58:33Z  The Late Boy Scout
# 11014  youtube#subscription  2020-11-14T01:33:57.263675Z              Pelton
#
#       channel_description                 channelId             sub_channelId  \
# 11012                 NaN  UCZgs5V2yHd_zHc4saV4_2_g  UCH7Fg32CH8sCW83gRxoxi8A
# 11013                 NaN  UCZjvj5MN3BMxPFfdEKIrvxQ  UCH7Fg32CH8sCW83gRxoxi8A
# 11014                 NaN  UCZl8xL7nG3eqzPfWc8wHMZw  UCH7Fg32CH8sCW83gRxoxi8A
#
#       pageToken
# 11012      none
# 11013      none
# 11014      none

# %%
current_chan_idx
# Out:
# 1190

# %%
df.sub_channelId.nunique()
# Out:
# 52

# %%
dfall.sub_channelId.nunique()
# Out:
# 507

# %% [markdown]
# ---
